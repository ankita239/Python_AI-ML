# %% [markdown]
# **List Some Mega Projects hosted in Python**

# %% [markdown]
# Some mega projects by python:
#
#   Database Projects: Management Systems (Library, Hotel, Hospital, School)
#
#    ML Projects: Classification
#
#   AI Projects: Chatbots, face detection and recognition, speech recognition, Security
#
#   Data Science Projects: Global Terrorism Analysis, Call Data Record Analysis

# %% [markdown]
# Some companies using python:
#
# -Netflix- main programming language
#
# -Facebook/Instagram – for developing VR hardwares and softwares
#
# -Google- Core is python + Java/Go
#
# -Reddit- Significant portion is made using python
#
# -Uber- Backend uses Node.js and Python + R
#
# -NASA
#
# -CIA

# %% [markdown]
# **List Python Libraries Used in Different IT Domains**

# %% [markdown]
# Pandas, numpy, matplotlib, tkinter, sklearn, tensorflow
#
# -For NLP(Natural Language Processing)/AI : NLTK, TextBlob, Pattern, etc.
#
# -For GUI(Graphical User Interface): Kivy, Tkinter, etc. (Game Development)
#
# -For web applications: Flask, Django,etc.

# %% [markdown]
# **Create a program and execute a script using python**

# %% [markdown]
# ![Picture1.jpg](attachment:Picture1.jpg)

# %% [markdown]
# ![Picture2.png](attachment:Picture2.png)

# %% [markdown]
# ![Picture3.png](attachment:Picture3.png)
